# %% [markdown]
# # Exercise Six: Structured Data with Beautiful Soup and Pandas
#
# By Marissa Salas
#
# I scraped metacritic.com for user reviews of The Boys to analyze user mentions of the character the Deep versus overall ratings of the show.

# %% [markdown]
# # Stage One: Import the libraries and Scrape your Page
#
# ## The libraries imported for Pandas, BeautifulSoup and requests. Requests is required when you ping a website or portal for information. Pandas is for data analysis. BeautifulSoup is python's web scraper.

# %%
#documented at: https://towardsdatascience.com/web-scraping-metacritic-reviews-using-beautifulsoup-63801bbe200e
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://www.metacritic.com/tv/the-boys/season-1/user-reviews'

user_agent = {'User-agent': 'Mozilla/5.0'}
response = requests.get(url, headers = user_agent)

soup = BeautifulSoup(response.text, 'html.parser')

#print(response.text)

# %% [markdown]
# # Stage Two: Define an Empty Dictionary Reflecting the Data Categories
#
# ## The data dictionary review_dict created and name, date, rating, and review are the defined categories.

# %%
review_dict = {'name':[], 'date':[], 'rating':[], 'review':[]}

# %% [markdown]
# # Stage Three: Loop through and Store Structured Data
#
# ## I looped through the data I pulled from the website.

# %%
for review in soup.find_all('div', class_='review_content'): 
    if review.find('div', class_='name') == None:
        break 
    review_dict['name'].append(review.find('div', class_='name').find('a').text)
    review_dict['date'].append(review.find('div', class_='date').text)
    review_dict['rating'].append(review.find('div', class_='review_grade').find_all('div')[0].text)
    if review.find('span', class_='blurb blurb_expanded'): 
        review_dict['review'].append(review.find('span', class_='blurb blurb_expanded').text)
        print(review.find('span', class_='blurb blurb_expanded').text)
    elif review.find('div',class_='review_body').find('span') == None:
        review_dict['review'].append('No review text.')
        print("No review")
    else:
        review_dict['review'].append(review.find('div',class_='review_body').find('span').text)
        print(review.find('div',class_='review_body').find('span').text)
# Out:
# Homelander is genuinely one of the best villains I’ve seen put to screen. Such a brilliantly reserved, nuanced and menancing display of acting. The story was great as well, with good pacing, and had me hooked throughout its 8 episode run time.
# I was pleasantly surprised. This isn't a show about superheros, rather it is about corruption, vengeance, and ego rather than it being about Superman fighting villain X. In fact, the show is a timely twist on the superhero genre. The good: good acting, strong world construction, believable characters, good dialogue, entertaining, and mentioned earlier, developed and well-done themes. The bad: the violence is slightly overdone (body parts and people explode every episode), but it is on par with modern TV these days (Rome, Game of Thrones, etc.).
# best show i've seen all year. i didn't know anything about the show when i saw it except that everyone was telling me to watch it.
# ...

# %% [markdown]
# # Stage Four: Convert from Dictionary to DataFrame and Display
#
# ## This is the conversion and resulting table, which is a preview of the top and bottom of the table.

# %%
ac_reviews = pd.DataFrame(review_dict)

# %%
ac_reviews
# Out:
#              name          date rating  \
# 0      im_so_meta  Jul 27, 2019     10
# 1   Spaulding1980  Aug  7, 2019      8
# 2          nurall  Nov 14, 2019     10
# 3        FireCard  Nov  6, 2019     10
# 4          JonDoc  Aug 13, 2019     10
# ..            ...           ...    ...
# 75   TudorPopescu  Oct 31, 2020     10
# 76      Johannes_  Sep 11, 2020      9
# 77    Beanbean801  Nov 15, 2020     10
# 78         geewah  Dec 24, 2020      9
# 79    iCampoRamil  May 29, 2021      7
#
#                                                review
# 0   Homelander is genuinely one of the best villai...
# 1   I was pleasantly surprised. This isn't a show ...
# 2   best show i've seen all year. i didn't know an...
# 3   8 hours of enjoiment. One of the best series n...
# 4   The is the new Game of Thrones.  Utterly compe...
# ..                                                ...
# 75  A gory, dark, mature anti-superhero series whi...
# ...

# %% [markdown]
# # Stage Five: Plot some Aspect of the Data

# %% [markdown]
# ## In this next stage, I review the data which includes looking at the descriptives and searching the reviews for mentions of the Deep.

# %%
ac_reviews.describe(include='all')
# Out:
#                  name          date rating  \
# count              80            80     80
# unique             80            54     11
# top     Ixidorsdreams  Jul 27, 2019     10
# freq                1             5     27
#
#                                                    review
# count                                                  80
# unique                                                 80
# top     Watch it!!!!!!!!!!!!!!! Watch it now!!!!! It’s...
# freq                                                    1

# %%
ac_reviews[ac_reviews['review'].str.contains('Deep','deep')]
# Out:
#                name          date rating  \
# 9        Angel_Sigh  Aug 12, 2019      8
# 16    Ixidorsdreams  Jul 27, 2019      8
# 52  ComandanteCobra  Aug  9, 2019      3
# 70       manningn15  Feb  6, 2021     10
# 74       pur__0_0__  Apr 25, 2021     10
#
#                                                review
# 9   I've only watched the first three episodes but...
# 16  I enjoyed the show very thoroughly thru five e...
# 52  It didn't amuse me sadly.\rIf you have some ye...
# 70  This is my favorite superhero tv show, my favo...
# 74  A few years back I was starting to gain some i...

# %% [markdown]
# ## This plot shows the top five reviewers and the number of times they mentioned the character the Deep and how they rated the show.

# %%
ac_reviews['rating'].value_counts()[:5].plot(kind="barh", title="Mentions of the Deep by Ratings of the Show")

# %% [markdown]
# ## Bonus Stage: Add On
#
# Try:
# - Iterating through multiple pages (all the pages of a database, for instance)
# - Visualizing using another method from our discussion or readings
# - Storing your data and / or visualization for external analysis

# %%
# This helped me visualize the data some more.

data = ac_reviews.sort_values(['rating'], axis=0, ascending=True)[:20]
data
# Out:
#               name          date rating  \
# 39   clifffranklin  Sep 20, 2020      0
# 44    myrabrandish  Sep 20, 2020      0
# 45   courtneyhaine  Sep 20, 2020      0
# 50  johnhomelander  Sep 22, 2020      0
# 51      hehasrisen  Sep 22, 2020      0
# 53       chuckyc45  Sep 21, 2020      0
# 54       petewh1te  Sep 21, 2020      0
# 63  empoweredsista  Sep 24, 2020      0
# 62     lutherlavay  Sep 23, 2020      0
# 56     Vechernyaya  Jul 26, 2019      1
# 40     Shaka_Igloo  Aug  9, 2019     10
# 36         andreag  Jul 26, 2019     10
# 34       papadrew7  Aug  1, 2019     10
# 37    Lightning123  Jul 28, 2019     10
# 38      insickness  Jul 30, 2019     10
# 32     Rooster7102  Aug  6, 2019     10
# 31    spartacus215  Jul 29, 2019     10
# 41         CloverX  Aug 10, 2019     10
# 48     MrFlankster  Jul 30, 2019     10
# 43   Notabotiswear  Jul 28, 2019     10
#
#                                                review
# 39  Rather than accept blame and show grace, Eric ...
# ...

# %% [markdown]
# ## This plot (even if messy) shows the greater numbers of user reviews rated this show at 7 or above. The zeros (0) are not considered.

# %%
ac_reviews.plot(kind = 'scatter', x = 'rating', y = 'name')

# %% [markdown]
# # Export to CSV and save the file that I scraped.

# %%
ac_reviews.to_csv(r'C:\Users\Streamer\Boysreview.csv')
